# %%
import pandas as pd

# %%
df = pd.read_excel('/content/dataset.xlsx')

# %%
df.head()
# Out:
#   Prompt No                     Prompt  \
# 0  Prompt_1  Describe a beautiful girl
# 1  Prompt_1  Describe a beautiful girl
# 2  Prompt_1  Describe a beautiful girl
# 3  Prompt_1  Describe a beautiful girl
# 4  Prompt_1  Describe a beautiful girl
#
#                                           Completion Student Name  Student_1  \
# 0  I would define beautiful girl who has a bright...    Student_1        0.7
# 1  She has a warm smile that lights up her face, ...    Student_2        0.7
# 2  She exudes confidence, with sparkling eyes and...    Student_3        0.8
# 3  A girl with a warm smile, kind eyes, and a con...    Student_4        0.4
# 4  Beauty is subjective, but a beautiful person i...    Student_5        0.5
#
#    Student_2  Student_3  Student_4  Student_5  Student_6  Student_7   Average  \
# 0       0.70        0.8        0.7        0.7        0.6        0.6  0.685714
# 1       0.65        0.7        0.8        0.9        0.7        0.7  0.735714
# ...

# %%
# Step 1: Filter columns that start with 'Student_' (e.g., 'Student_1', 'Student_2', ...)
student_cols = df.filter(regex='^Student_').columns

# Step 2: Calculate the average score across all 'Student_' columns for each row (axis=1 means row-wise)
df['AVG'] = df[student_cols].mean(axis=1)

# Step 3: Calculate the Difference from Class Average (DCS)
# For each row, calculate the difference between the student's score and the average score
df['DCS'] = df.apply(lambda row:
    # Access the student's score dynamically based on the 'Student Name' column
    row[f"Student_{int(row['Student Name'].split('_')[1])}"] - row['AVG']
    # If the dynamic 'Student_X' column exists, calculate DCS, otherwise set it as NaN
    if f"Student_{int(row['Student Name'].split('_')[1])}" in df.columns else np.nan, axis=1)

# %%
# Save the modified dataframe back to an Excel file
df.to_excel('output_with_updated_dcs.xlsx', index=False)
